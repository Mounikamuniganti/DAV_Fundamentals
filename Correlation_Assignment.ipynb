# %% [markdown]
# <a href="https://colab.research.google.com/github/Mounikamuniganti/DAV_Fundamentals/blob/main/Correlation_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import pearsonr, spearmanr, ttest_rel

# %% [markdown]
# # **Q1. Correlation and Covariance**
#
# Given correlation coefficient between X and Y as 0.7 and covariance between the same as 73, what is variance of Y if variance of X is 25?

# %%
rho=0.7

# %% [markdown]
# # **Q2. Correlation Analysis**
#
# Consider the below plot for two continuous variables:
#
# https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/003/108/original/corr_qb.PNG?1649061008
#
# Based on this plot, which of the following option is correct?

# %%
There is absolutely no relation between the two variables and it can be concluded that these two variables are completely independent of each other

# %% [markdown]
# # Q3. Interpret **Correlation** **bold text**
#
# Based on the following plots, arrange them in descending order with respect to their correlation values.
#
# i)
#
# ![image.png](data:image/png;base64,...)
#
# ii)
#
# ![image.png](data:image/png;base64,...)
#
# iii)
#
# ![image.png](data:image/png;base64,...)
#
# iv)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **iv > ii > iii > i**

# %% [markdown]
# # **Q4. Pearson vs Spearman**
#
# Choose the correct statement(s) on Pearson Correlation Coefficient and Spearman Rank Correlation Coefficient.
#
#
# Correct options:
#
# Pearson gives a measure of strength of linear association between two variables where as Spearman gives a measure of strength of monotonicity between two variables.
#
#
# Pearson is calculated from the raw value of data points where as Spearman depends on the rank.
#
#
# Both the techniques cannot be used with nominal data

# %% [markdown]
# # **Q5. Correlation plots**
#
# Based on Spearman's rank correlation, order the below plots from highest to lowest correlation.
#
# ![image.png](data:image/png;base64,...)
#
#
# Answer: C,A,B,D

# %% [markdown]
# # **Q6. mRNA Genes**
#
# Suppose we have mRNA data with features as Gene ‘X’ and Gene ‘Y’. You get to know that there is a correlation between these features. Based on the correlation type, what conclusion can you make?
#
# ![image.png](data:image/png;base64,...)
#
#
# Answer: 1-c, 2-a,3-b

# %% [markdown]
# # **Q7. Zumba trainer**
#
# The Zumba trainer claims to the customers, that their new dance routine helps to reduce more weight.
#
# Weight of 8 people were recorded before and after following the new Zumba training for a month:
#
# wt_before = [85, 74, 63.5, 69.4, 71.6, 65,90,78]
#
#
# wt_after = [82, 71, 64, 65.2, 67.8, 64.7,95,77]
#
# Test the trainer's claim with 90% confidence. Further, what would be the pvalue?

# %%
#H0: Customers did not reduce their weight after 1 month of new Zumba routine (μ Before =μ After)
#H1: Customers have reduced their weight after 1 month of new Zumba routine (μ Before > μ After)

'''
The nature of data here is in the form of “Before” and “After” the new Zumba dance routine.

Hence we will use Paired T-test using ttest_rel()

Further, in order to test our proposed alternate hypothesis, we would have to perform Right Tail test
'''

wt_before = [85, 74, 63.5, 69.4, 71.6, 65,90,78]
wt_after = [82, 71, 64, 65.2, 67.8, 64.7,95,77]

alpha = 0.10 # Significance level

# Performing Paired Right-Tailed T-test
t_stat, pvalue = ttest_rel(wt_before, wt_after, alternative="greater" )
print('Test Statistic:', t_stat)
print('P value:', pvalue)

if pvalue < alpha:
  print('Reject H0 ; Customers have reduced their weight after 1 month of new Zumba routine')
else:
  print('Fail to reject H0 ; Customers did not reduce their weight after 1 month of new Zumba routine')
# Out:
# Test Statistic: 1.1421853793555032
# P value: 0.14546808501326386
# Fail to reject H0 ; Customers did not reduce their weight after 1 month of new Zumba routine

# %% [markdown]
# # **Q8. Test the Training Program**
#
# You are appointed as a Data Analyst for a training program deployed by the Government of India.
#
# The participants’ skills were tested before and after the training using some metrics on a scale of 10.
#
#
# before = [2.45, 0.69, 1.80, 2.80, 0.07, 1.67, 2.93, 0.47, 1.45, 1.34]
#
#
# after = [7.71, 2.17, 5.65, 8.79, 0.23, 5.23, 9.19, 1.49, 4.56, 4.20]
#
# Conduct an appropriate test to assess a statistically significant increase in the average skill score after the training program, and then answer the below questions accordingly.
#
# Note: Perform the test at alpha = 5%.

# %%
#Ho: There is no increase in the average skill score after the training program
#Ha: There is increase in the average skill score after the training program

before = [2.45, 0.69, 1.80, 2.80, 0.07, 1.67, 2.93, 0.47, 1.45, 1.34]
after = [7.71, 2.17, 5.65, 8.79, 0.23, 5.23, 9.19, 1.49, 4.56, 4.20]

alpha = 0.05 # Significance level

# Performing Paired Right-Tailed T-test
t_stat, pvalue = ttest_rel(before, after, alternative="greater" )
print('Test Statistic:', t_stat)
print('P value:', pvalue)

if pvalue < alpha:
  print('Reject H0 ; There is increase in the average skill score after the training program')
else:
  print('Fail to reject H0 ; There is no increase in the average skill score after the training program')
# Out:
# Test Statistic: -5.111096450191605
# P value: 0.9996822188018052
# Fail to reject H0 ; There is no increase in the average skill score after the training program
